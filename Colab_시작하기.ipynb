# %% [markdown]
# <a href="https://colab.research.google.com/github/lhmpia/colab/blob/main/Colab_%EC%8B%9C%EC%9E%91%ED%95%98%EA%B8%B0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("한영해 구글...")
# Out:
# 한영해 구글...

# %%
data = input("오늘 몇시 퇴근")
# Out:
# 오늘 몇시 퇴근6시
